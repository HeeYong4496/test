# %%
# -*- coding: utf-8 -*-
# 코드 내부에 한글을 사용가능 하게 해주는 부분입니다.

# 딥러닝을 구동하는 데 필요한 케라스 함수를 불러옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 필요한 라이브러리를 불러옵니다.
import numpy as np
import tensorflow as tf

# 실행할 때마다 같은 결과를 출력하기 위해 설정하는 부분입니다.
np.random.seed(3)
tf.random.set_seed(3)

# 준비된 수술 환자 데이터를 불러들입니다.
Data_set = np.loadtxt("/content/drive/MyDrive/ThoraricSurgery.csv", delimiter=",")

# 환자의 기록과 수술 결과를 X와 Y로 구분하여 저장합니다.
X = Data_set[:,0:17]
Y = Data_set[:,17]

# 딥러닝 구조를 결정합니다(모델을 설정하고 실행하는 부분입니다).
model = Sequential()
model.add(Dense(30, input_dim=17, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


# 딥러닝을 실행합니다.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 1ms/step - loss: 0.8781 - accuracy: 0.7774
# Epoch 2/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4637 - accuracy: 0.8707
# Epoch 3/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4652 - accuracy: 0.8347
# Epoch 4/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.5176 - accuracy: 0.8405
# Epoch 5/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4461 - accuracy: 0.8570
# Epoch 6/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4391 - accuracy: 0.8523
# Epoch 7/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4616 - accuracy: 0.8443
# Epoch 8/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4523 - accuracy: 0.8447
# Epoch 9/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3877 - accuracy: 0.8618
# Epoch 10/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3944 - accuracy: 0.8697
# Epoch 11/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4379 - accuracy: 0.8480
# Epoch 12/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4470 - accuracy: 0.8449
# Epoch 13/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.8302
# Epoch 14/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4402 - accuracy: 0.8438
# Epoch 15/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4928 - accuracy: 0.8220
# Epoch 16/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4119 - accuracy: 0.8534
# Epoch 17/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4383 - accuracy: 0.8564
# Epoch 18/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4807 - accuracy: 0.8556
# Epoch 19/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4253 - accuracy: 0.8459
# Epoch 20/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4403 - accuracy: 0.8561
# Epoch 21/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4191 - accuracy: 0.8513
# Epoch 22/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4100 - accuracy: 0.8554
# Epoch 23/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4205 - accuracy: 0.8538
# Epoch 24/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4226 - accuracy: 0.8471
# Epoch 25/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4349 - accuracy: 0.8394
# Epoch 26/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4526 - accuracy: 0.8552
# Epoch 27/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4590 - accuracy: 0.8312
# Epoch 28/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4469 - accuracy: 0.8461
# Epoch 29/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3775 - accuracy: 0.8803
# Epoch 30/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3581 - accuracy: 0.8892
# Epoch 31/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4157 - accuracy: 0.8745
# Epoch 32/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4037 - accuracy: 0.8639
# Epoch 33/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4367 - accuracy: 0.8560
# Epoch 34/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3961 - accuracy: 0.8582
# Epoch 35/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4047 - accuracy: 0.8514
# Epoch 36/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4423 - accuracy: 0.8340
# Epoch 37/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4449 - accuracy: 0.8519
# Epoch 38/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4314 - accuracy: 0.8452
# Epoch 39/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4797 - accuracy: 0.8291
# Epoch 40/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4177 - accuracy: 0.8508
# Epoch 41/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4472 - accuracy: 0.8508
# Epoch 42/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4340 - accuracy: 0.8517
# Epoch 43/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3614 - accuracy: 0.8727
# Epoch 44/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3523 - accuracy: 0.8783
# Epoch 45/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3800 - accuracy: 0.8555
# Epoch 46/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4116 - accuracy: 0.8546
# Epoch 47/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8812
# Epoch 48/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3902 - accuracy: 0.8645
# Epoch 49/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4169 - accuracy: 0.8361
# Epoch 50/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3604 - accuracy: 0.8783
# Epoch 51/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4260 - accuracy: 0.8457
# Epoch 52/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4176 - accuracy: 0.8520
# Epoch 53/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4213 - accuracy: 0.8481
# Epoch 54/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4200 - accuracy: 0.8348
# Epoch 55/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4092 - accuracy: 0.8632
# Epoch 56/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3982 - accuracy: 0.8476
# Epoch 57/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4001 - accuracy: 0.8525
# Epoch 58/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3528 - accuracy: 0.8703
# Epoch 59/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4201 - accuracy: 0.8475
# Epoch 60/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3578 - accuracy: 0.8774
# Epoch 61/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3907 - accuracy: 0.8725
# Epoch 62/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4215 - accuracy: 0.8389
# Epoch 63/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3711 - accuracy: 0.8686
# Epoch 64/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4243 - accuracy: 0.8525
# Epoch 65/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3775 - accuracy: 0.8639
# Epoch 66/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4256 - accuracy: 0.8517
# Epoch 67/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3803 - accuracy: 0.8612
# Epoch 68/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4071 - accuracy: 0.8624
# Epoch 69/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4336 - accuracy: 0.8197
# Epoch 70/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4068 - accuracy: 0.8519
# Epoch 71/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4412 - accuracy: 0.8194
# Epoch 72/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3777 - accuracy: 0.8554
# Epoch 73/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4042 - accuracy: 0.8489
# Epoch 74/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3783 - accuracy: 0.8595
# Epoch 75/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3516 - accuracy: 0.8812
# Epoch 76/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3733 - accuracy: 0.8629
# Epoch 77/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4473 - accuracy: 0.8247
# Epoch 78/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3992 - accuracy: 0.8696
# Epoch 79/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4184 - accuracy: 0.8299
# Epoch 80/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4250 - accuracy: 0.8335
# Epoch 81/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3712 - accuracy: 0.8793
# Epoch 82/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4214 - accuracy: 0.8487
# Epoch 83/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4450 - accuracy: 0.8381
# Epoch 84/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3537 - accuracy: 0.8840
# Epoch 85/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3822 - accuracy: 0.8617
# Epoch 86/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3410 - accuracy: 0.8688
# Epoch 87/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3933 - accuracy: 0.8567
# Epoch 88/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3747 - accuracy: 0.8538
# Epoch 89/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3942 - accuracy: 0.8320
# Epoch 90/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3722 - accuracy: 0.8768
# Epoch 91/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4208 - accuracy: 0.8516
# Epoch 92/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4239 - accuracy: 0.8407
# Epoch 93/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4079 - accuracy: 0.8362
# Epoch 94/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3913 - accuracy: 0.8367
# Epoch 95/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4023 - accuracy: 0.8584
# Epoch 96/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4342 - accuracy: 0.8596
# Epoch 97/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4469 - accuracy: 0.8137
# Epoch 98/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3893 - accuracy: 0.8690
# Epoch 99/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3737 - accuracy: 0.8620
# Epoch 100/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8330

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %%
import numpy as np

x = [2, 4, 6, 8]
y = [81, 93, 91, 97]

mx = np.mean(x)
my = np.mean(y)

print("x의 평균 :", mx)
print("y의 평균 :", my)

divisor = sum([(mx - i) **2 for i in x])

def top(x, mx, y, my):
  d = 0
  for i in range(len(x)):
    d += (x[i] - mx) * (y[i] - my)
  return d
devidend = top(x, mx, y, my)

print("분모 :", divisor)
print("분자 :", devidend)

a = devidend / divisor
b = my - (mx*a)

print("기울기 :", a)
print("y 절편 b:", b)
# Out:
# x의 평균 : 5.0
# y의 평균 : 90.5
# 분모 : 20.0
# 분자 : 46.0
# 기울기 : 2.3
# y 절편 b: 79.0

# %%
fake_a_b = [3, 76]
data = [[2,81], [4, 93], [6,91], [8, 97]]

x=[i[0] for i in data]
y=[i[1] for i in data]

def predict(x):
  return fake_a_b[0]*x + fake_a_b[1]
def mse(y, y_hat):
  return ((y-y_hat) **2).mean()

def mse_val(y, predict_result):
  return mse(np.array(y), np.array(predict_result))

predict_result = []  

for i in range(len(x)):
  predict_result.append(predict(x[i]))
  print("공부한 시간=%.f, 실제 점수=%.f, 예측 점수=%.f" % (x[i], y[i], predict(x[i])))

print("mse 최종값=" + str(mse_val(predict_result, y)))
# Out:
# 공부한 시간=2, 실제 점수=81, 예측 점수=82
# 공부한 시간=4, 실제 점수=93, 예측 점수=88
# 공부한 시간=6, 실제 점수=91, 예측 점수=94
# 공부한 시간=8, 실제 점수=97, 예측 점수=100
# mse 최종값=11.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#공부시간 X와 성적 Y의 리스트를 만듭니다.
data = [[2, 81], [4, 93], [6, 91], [8, 97]]
x = [i[0] for i in data]
y = [i[1] for i in data]

#그래프로 나타내 봅니다.
plt.figure(figsize=(8,5))
plt.scatter(x, y)
plt.show()

# %%
x_data = np.array(x)
y_data = np.array(y)
a = 0
b = 0
lr = 0.03
epochs = 2001

for i in range(epochs): 
    y_hat = a * x_data + b 
    error = y_hat - y_data  
    a_diff = (2/len(x_data)) * sum(x_data * (error))  
    b_diff = (2/len(x_data)) * sum(error)   
    a = a - lr * a_diff  
    b = b - lr * b_diff

    if i % 100 == 0:  
        print("epoch=%.f, 기울기=%.04f, 절편=%.04f" % (i, a, b))
# Out:
# epoch=0, 기울기=27.8400, 절편=5.4300
# epoch=100, 기울기=7.0739, 절편=50.5117
# epoch=200, 기울기=4.0960, 절편=68.2822
# epoch=300, 기울기=2.9757, 절편=74.9678
# epoch=400, 기울기=2.5542, 절편=77.4830
# epoch=500, 기울기=2.3956, 절편=78.4293
# epoch=600, 기울기=2.3360, 절편=78.7853
# epoch=700, 기울기=2.3135, 절편=78.9192
# epoch=800, 기울기=2.3051, 절편=78.9696
# epoch=900, 기울기=2.3019, 절편=78.9886
# epoch=1000, 기울기=2.3007, 절편=78.9957
# epoch=1100, 기울기=2.3003, 절편=78.9984
# epoch=1200, 기울기=2.3001, 절편=78.9994
# epoch=1300, 기울기=2.3000, 절편=78.9998
# epoch=1400, 기울기=2.3000, 절편=78.9999
# epoch=1500, 기울기=2.3000, 절편=79.0000
# epoch=1600, 기울기=2.3000, 절편=79.0000
# epoch=1700, 기울기=2.3000, 절편=79.0000
# epoch=1800, 기울기=2.3000, 절편=79.0000
# epoch=1900, 기울기=2.3000, 절편=79.0000
# epoch=2000, 기울기=2.3000, 절편=79.0000

# %%
y_pred = a * x_data + b
plt.scatter(x, y)
plt.plot([min(x_data), max(x_data)], [min(y_pred), max(y_pred)])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

#공부시간 X와 성적 Y의 리스트를 만듭니다.
data = [[2, 0, 81], [4, 4, 93], [6, 2, 91], [8, 3, 97]]
x1 = [i[0] for i in data]
x2 = [i[1] for i in data]
y = [i[2] for i in data]

#그래프로 확인해 봅니다.
ax = plt.axes(projection='3d')
ax.set_xlabel('study_hours')
ax.set_ylabel('private_class')
ax.set_zlabel('Score')
ax.dist = 11 
ax.scatter(x1, x2, y)
plt.show()

# %%
x1_data = np.array(x1)
x2_data = np.array(x2)
y_data = np.array(y)

# 기울기 a와 절편 b의 값을 초기화 합니다.
a1 = 0
a2 = 0
b = 0

#학습률을 정합니다.
lr = 0.02 

#몇 번 반복될지를 설정합니다.(0부터 세므로 원하는 반복 횟수에 +1을 해 주어야 합니다.)
epochs = 3001 

#경사 하강법을 시작합니다.
for i in range(epochs): # epoch 수 만큼 반복
    y_pred = a1 * x1_data + a2 * x2_data + b  #y를 구하는 식을 세웁니다
    error = y_data - y_pred  #오차를 구하는 식입니다.
    a1_diff = -(2/len(x1_data)) * sum(x1_data * (error)) # 오차함수를 a1로 미분한 값입니다. 
    a2_diff = -(2/len(x2_data)) * sum(x2_data * (error)) # 오차함수를 a2로 미분한 값입니다. 
    b_new = -(2/len(x1_data)) * sum(y_data - y_pred)  # 오차함수를 b로 미분한 값입니다. 
    a1 = a1 - lr * a1_diff  # 학습률을 곱해 기존의 a1값을 업데이트합니다.
    a2 = a2 - lr * a2_diff  # 학습률을 곱해 기존의 a2값을 업데이트합니다.
    b = b - lr * b_new  # 학습률을 곱해 기존의 b값을 업데이트합니다.
    if i % 100 == 0:    # 100번 반복될 때마다 현재의 a1, a2, b값을 출력합니다.
        print("epoch=%.f, 기울기1=%.04f, 기울기2=%.04f, 절편=%.04f" % (i, a1, a2, b))
# Out:
# epoch=0, 기울기1=18.5600, 기울기2=8.4500, 절편=3.6200
# epoch=100, 기울기1=7.2994, 기울기2=4.2867, 절편=38.0427
# epoch=200, 기울기1=4.5683, 기울기2=3.3451, 절편=56.7901
# epoch=300, 기울기1=3.1235, 기울기2=2.8463, 절편=66.7100
# epoch=400, 기울기1=2.3591, 기울기2=2.5823, 절편=71.9589
# epoch=500, 기울기1=1.9546, 기울기2=2.4427, 절편=74.7362
# epoch=600, 기울기1=1.7405, 기울기2=2.3688, 절편=76.2058
# epoch=700, 기울기1=1.6273, 기울기2=2.3297, 절편=76.9833
# epoch=800, 기울기1=1.5673, 기울기2=2.3090, 절편=77.3948
# epoch=900, 기울기1=1.5356, 기울기2=2.2980, 절편=77.6125
# epoch=1000, 기울기1=1.5189, 기울기2=2.2922, 절편=77.7277
# epoch=1100, 기울기1=1.5100, 기울기2=2.2892, 절편=77.7886
# epoch=1200, 기울기1=1.5053, 기울기2=2.2875, 절편=77.8209
# epoch=1300, 기울기1=1.5028, 기울기2=2.2867, 절편=77.8380
# epoch=1400, 기울기1=1.5015, 기울기2=2.2862, 절편=77.8470
# epoch=1500, 기울기1=1.5008, 기울기2=2.2860, 절편=77.8518
# epoch=1600, 기울기1=1.5004, 기울기2=2.2859, 절편=77.8543
# epoch=1700, 기울기1=1.5002, 기울기2=2.2858, 절편=77.8556
# epoch=1800, 기울기1=1.5001, 기울기2=2.2858, 절편=77.8563
# epoch=1900, 기울기1=1.5001, 기울기2=2.2857, 절편=77.8567
# epoch=2000, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8569
# epoch=2100, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8570
# epoch=2200, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=2300, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=2400, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=2500, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=2600, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=2700, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=2800, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=2900, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571
# epoch=3000, 기울기1=1.5000, 기울기2=2.2857, 절편=77.8571

# %%
import statsmodels.api as statm
import statsmodels.formula.api as statfa
#from matplotlib.pyplot import figure

X = [i[0:2] for i in data]
y = [i[2] for i in data]

X_1=statm.add_constant(X)
results=statm.OLS(y,X_1).fit()

hour_class=pd.DataFrame(X,columns=['study_hours','private_class'])
hour_class['Score']=pd.Series(y)

model = statfa.ols(formula='Score ~ study_hours + private_class', data=hour_class)

results_formula = model.fit()

a, b = np.meshgrid(np.linspace(hour_class.study_hours.min(),hour_class.study_hours.max(),100),
                   np.linspace(hour_class.private_class.min(),hour_class.private_class.max(),100))

X_ax = pd.DataFrame({'study_hours': a.ravel(), 'private_class': b.ravel()})
fittedY=results_formula.predict(exog=X_ax)

fig = plt.figure()
graph = fig.add_subplot(111, projection='3d')

graph.scatter(hour_class['study_hours'],hour_class['private_class'],hour_class['Score'],
              c='blue',marker='o', alpha=1)
graph.plot_surface(a,b,fittedY.values.reshape(a.shape),
                   rstride=1, cstride=1, color='none', alpha=0.4)
graph.set_xlabel('study hours')
graph.set_ylabel('private class')
graph.set_zlabel('Score')
graph.dist = 11

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#공부시간 X와 성적 Y의 리스트를 만듭니다.
data = [[2, 0], [4, 0], [6, 0], [8, 1], [10, 1], [12, 1], [14, 1]]

x_data = [i[0] for i in data]
y_data = [i[1] for i in data]

#그래프로 나타내 봅니다.
plt.scatter(x_data, y_data)
plt.xlim(0, 15)
plt.ylim(-.1, 1.1)
# Out:
# (-0.1, 1.1)

# %%
a = 0
b = 0

#학습률을 정합니다.
lr = 0.05 

#시그모이드 함수를 정의합니다.
def sigmoid(x):
    return 1 / (1 + np.e ** (-x))

# %%
for i in range(3001):
  for x_data, y_data in data:
    a_diff = x_data*(sigmoid(a*x_data + b) - y_data)
    b_diff = sigmoid(a*x_data + b) - y_data
    a = a - lr * a_diff
    b = b - lr * b_diff
    if i % 100 == 0:
      print("epoch=%.f,  기울기=%.04f,  절편=%.04f" % (i, a, b))
# Out:
# epoch=0,  기울기=-0.0500,  절편=-0.0250
# epoch=0,  기울기=-0.1388,  절편=-0.0472
# epoch=0,  기울기=-0.2268,  절편=-0.0619
# epoch=0,  기울기=0.1201,  절편=-0.0185
# epoch=0,  기울기=0.2374,  절편=-0.0068
# epoch=0,  기울기=0.2705,  절편=-0.0040
# epoch=0,  기울기=0.2860,  절편=-0.0029
# epoch=100,  기울기=0.6308,  절편=-3.2327
# epoch=100,  기울기=0.5649,  절편=-3.2492
# epoch=100,  기울기=0.4044,  절편=-3.2759
# epoch=100,  기울기=0.6085,  절편=-3.2504
# epoch=100,  기울기=0.6362,  절편=-3.2476
# epoch=100,  기울기=0.6436,  절편=-3.2470
# epoch=100,  기울기=0.6458,  절편=-3.2469
# epoch=200,  기울기=0.8310,  절편=-4.8166
# epoch=200,  기울기=0.7942,  절편=-4.8258
# epoch=200,  기울기=0.6488,  절편=-4.8500
# epoch=200,  기울기=0.8151,  절편=-4.8292
# epoch=200,  기울기=0.8325,  절편=-4.8275
# epoch=200,  기울기=0.8359,  절편=-4.8272
# epoch=200,  기울기=0.8366,  절편=-4.8272
# epoch=300,  기울기=0.9686,  절편=-5.8997
# epoch=300,  기울기=0.9453,  절편=-5.9056
# epoch=300,  기울기=0.8127,  절편=-5.9276
# epoch=300,  기울기=0.9568,  절편=-5.9096
# epoch=300,  기울기=0.9694,  절편=-5.9084
# epoch=300,  기울기=0.9714,  절편=-5.9082
# epoch=300,  기울기=0.9717,  절편=-5.9082
# epoch=400,  기울기=1.0771,  절편=-6.7449
# epoch=400,  기울기=1.0611,  절편=-6.7489
# epoch=400,  기울기=0.9394,  절편=-6.7692
# epoch=400,  기울기=1.0681,  절편=-6.7531
# epoch=400,  기울기=1.0777,  절편=-6.7521
# epoch=400,  기울기=1.0790,  절편=-6.7520
# epoch=400,  기울기=1.0791,  절편=-6.7520
# epoch=500,  기울기=1.1684,  절편=-7.4486
# epoch=500,  기울기=1.1567,  절편=-7.4516
# epoch=500,  기울기=1.0442,  절편=-7.4703
# epoch=500,  기울기=1.1612,  절편=-7.4557
# epoch=500,  기울기=1.1689,  절편=-7.4549
# epoch=500,  기울기=1.1698,  절편=-7.4549
# epoch=500,  기울기=1.1698,  절편=-7.4548
# epoch=600,  기울기=1.2480,  절편=-8.0575
# epoch=600,  기울기=1.2391,  절편=-8.0597
# epoch=600,  기울기=1.1345,  절편=-8.0771
# epoch=600,  기울기=1.2422,  절편=-8.0637
# epoch=600,  기울기=1.2485,  절편=-8.0630
# epoch=600,  기울기=1.2491,  절편=-8.0630
# epoch=600,  기울기=1.2491,  절편=-8.0630
# epoch=700,  기울기=1.3191,  절편=-8.5973
# epoch=700,  기울기=1.3121,  절편=-8.5991
# epoch=700,  기울기=1.2143,  절편=-8.6154
# epoch=700,  기울기=1.3143,  절편=-8.6029
# epoch=700,  기울기=1.3196,  절편=-8.6023
# epoch=700,  기울기=1.3200,  절편=-8.6023
# epoch=700,  기울기=1.3200,  절편=-8.6023
# epoch=800,  기울기=1.3836,  절편=-9.0844
# epoch=800,  기울기=1.3780,  절편=-9.0858
# epoch=800,  기울기=1.2861,  절편=-9.1011
# epoch=800,  기울기=1.3796,  절편=-9.0894
# epoch=800,  기울기=1.3841,  절편=-9.0890
# epoch=800,  기울기=1.3844,  절편=-9.0889
# epoch=800,  기울기=1.3844,  절편=-9.0889
# epoch=900,  기울기=1.4429,  절편=-9.5294
# epoch=900,  기울기=1.4383,  절편=-9.5306
# epoch=900,  기울기=1.3516,  절편=-9.5450
# epoch=900,  기울기=1.4395,  절편=-9.5340
# epoch=900,  기울기=1.4433,  절편=-9.5337
# epoch=900,  기울기=1.4436,  절편=-9.5336
# epoch=900,  기울기=1.4436,  절편=-9.5336
# epoch=1000,  기울기=1.4978,  절편=-9.9401
# epoch=1000,  기울기=1.4940,  절편=-9.9411
# epoch=1000,  기울기=1.4120,  절편=-9.9547
# epoch=1000,  기울기=1.4949,  절편=-9.9444
# epoch=1000,  기울기=1.4982,  절편=-9.9440
# epoch=1000,  기울기=1.4984,  절편=-9.9440
# epoch=1000,  기울기=1.4985,  절편=-9.9440
# epoch=1100,  기울기=1.5491,  절편=-10.3220
# epoch=1100,  기울기=1.5459,  절편=-10.3228
# epoch=1100,  기울기=1.4680,  절편=-10.3358
# epoch=1100,  기울기=1.5466,  절편=-10.3260
# epoch=1100,  기울기=1.5495,  절편=-10.3257
# epoch=1100,  기울기=1.5497,  절편=-10.3257
# epoch=1100,  기울기=1.5497,  절편=-10.3257
# epoch=1200,  기울기=1.5973,  절편=-10.6795
# epoch=1200,  기울기=1.5946,  절편=-10.6801
# epoch=1200,  기울기=1.5204,  절편=-10.6925
# epoch=1200,  기울기=1.5951,  절편=-10.6832
# epoch=1200,  기울기=1.5977,  절편=-10.6829
# epoch=1200,  기울기=1.5978,  절편=-10.6829
# epoch=1200,  기울기=1.5978,  절편=-10.6829
# epoch=1300,  기울기=1.6427,  절편=-11.0157
# epoch=1300,  기울기=1.6404,  절편=-11.0163
# epoch=1300,  기울기=1.5696,  절편=-11.0281
# epoch=1300,  기울기=1.6409,  절편=-11.0192
# epoch=1300,  기울기=1.6431,  절편=-11.0190
# epoch=1300,  기울기=1.6432,  절편=-11.0189
# epoch=1300,  기울기=1.6432,  절편=-11.0189
# epoch=1400,  기울기=1.6858,  절편=-11.3334
# epoch=1400,  기울기=1.6838,  절편=-11.3339
# epoch=1400,  기울기=1.6160,  절편=-11.3452
# epoch=1400,  기울기=1.6842,  절편=-11.3367
# epoch=1400,  기울기=1.6862,  절편=-11.3365
# epoch=1400,  기울기=1.6863,  절편=-11.3365
# epoch=1400,  기울기=1.6863,  절편=-11.3365
# epoch=1500,  기울기=1.7268,  절편=-11.6347
# epoch=1500,  기울기=1.7250,  절편=-11.6352
# epoch=1500,  기울기=1.6600,  절편=-11.6460
# epoch=1500,  기울기=1.7253,  절편=-11.6378
# epoch=1500,  기울기=1.7271,  절편=-11.6377
# epoch=1500,  기울기=1.7272,  절편=-11.6376
# epoch=1500,  기울기=1.7272,  절편=-11.6376
# epoch=1600,  기울기=1.7658,  절편=-11.9214
# epoch=1600,  기울기=1.7643,  절편=-11.9218
# epoch=1600,  기울기=1.7018,  절편=-11.9322
# epoch=1600,  기울기=1.7646,  절편=-11.9244
# epoch=1600,  기울기=1.7662,  절편=-11.9242
# epoch=1600,  기울기=1.7662,  절편=-11.9242
# epoch=1600,  기울기=1.7662,  절편=-11.9242
# epoch=1700,  기울기=1.8032,  절편=-12.1951
# epoch=1700,  기울기=1.8018,  절편=-12.1954
# epoch=1700,  기울기=1.7417,  절편=-12.2054
# epoch=1700,  기울기=1.8021,  절편=-12.1979
# epoch=1700,  기울기=1.8035,  절편=-12.1977
# epoch=1700,  기울기=1.8036,  절편=-12.1977
# epoch=1700,  기울기=1.8036,  절편=-12.1977
# epoch=1800,  기울기=1.8390,  절편=-12.4568
# epoch=1800,  기울기=1.8378,  절편=-12.4571
# epoch=1800,  기울기=1.7799,  절편=-12.4668
# epoch=1800,  기울기=1.8380,  절편=-12.4595
# epoch=1800,  기울기=1.8393,  절편=-12.4594
# epoch=1800,  기울기=1.8394,  절편=-12.4594
# epoch=1800,  기울기=1.8394,  절편=-12.4594
# epoch=1900,  기울기=1.8734,  절편=-12.7078
# epoch=1900,  기울기=1.8723,  절편=-12.7080
# epoch=1900,  기울기=1.8164,  절편=-12.7174
# epoch=1900,  기울기=1.8725,  절편=-12.7104
# epoch=1900,  기울기=1.8737,  절편=-12.7102
# epoch=1900,  기울기=1.8737,  절편=-12.7102
# epoch=1900,  기울기=1.8737,  절편=-12.7102
# epoch=2000,  기울기=1.9065,  절편=-12.9489
# epoch=2000,  기울기=1.9055,  절편=-12.9491
# epoch=2000,  기울기=1.8515,  절편=-12.9581
# epoch=2000,  기울기=1.9057,  절편=-12.9514
# epoch=2000,  기울기=1.9068,  절편=-12.9513
# epoch=2000,  기울기=1.9068,  절편=-12.9513
# epoch=2000,  기울기=1.9068,  절편=-12.9513
# epoch=2100,  기울기=1.9384,  절편=-13.1810
# epoch=2100,  기울기=1.9375,  절편=-13.1812
# epoch=2100,  기울기=1.8852,  절편=-13.1899
# epoch=2100,  기울기=1.9376,  절편=-13.1833
# epoch=2100,  기울기=1.9387,  절편=-13.1832
# epoch=2100,  기울기=1.9387,  절편=-13.1832
# epoch=2100,  기울기=1.9387,  절편=-13.1832
# epoch=2200,  기울기=1.9692,  절편=-13.4047
# epoch=2200,  기울기=1.9684,  절편=-13.4049
# epoch=2200,  기울기=1.9177,  절편=-13.4133
# epoch=2200,  기울기=1.9685,  절편=-13.4070
# epoch=2200,  기울기=1.9694,  절편=-13.4069
# epoch=2200,  기울기=1.9695,  절편=-13.4069
# epoch=2200,  기울기=1.9695,  절편=-13.4069
# epoch=2300,  기울기=1.9989,  절편=-13.6207
# epoch=2300,  기울기=1.9982,  절편=-13.6209
# epoch=2300,  기울기=1.9491,  절편=-13.6291
# epoch=2300,  기울기=1.9983,  절편=-13.6229
# epoch=2300,  기울기=1.9992,  절편=-13.6228
# epoch=2300,  기울기=1.9992,  절편=-13.6228
# epoch=2300,  기울기=1.9992,  절편=-13.6228
# epoch=2400,  기울기=2.0277,  절편=-13.8296
# epoch=2400,  기울기=2.0271,  절편=-13.8297
# epoch=2400,  기울기=1.9794,  절편=-13.8377
# epoch=2400,  기울기=2.0272,  절편=-13.8317
# epoch=2400,  기울기=2.0280,  절편=-13.8316
# epoch=2400,  기울기=2.0280,  절편=-13.8316
# epoch=2400,  기울기=2.0280,  절편=-13.8316
# epoch=2500,  기울기=2.0557,  절편=-14.0318
# epoch=2500,  기울기=2.0551,  절편=-14.0319
# epoch=2500,  기울기=2.0088,  절편=-14.0396
# epoch=2500,  기울기=2.0552,  절편=-14.0338
# epoch=2500,  기울기=2.0559,  절편=-14.0337
# epoch=2500,  기울기=2.0559,  절편=-14.0337
# epoch=2500,  기울기=2.0559,  절편=-14.0337
# epoch=2600,  기울기=2.0828,  절편=-14.2277
# epoch=2600,  기울기=2.0822,  절편=-14.2278
# epoch=2600,  기울기=2.0372,  절편=-14.2353
# epoch=2600,  기울기=2.0823,  절편=-14.2297
# epoch=2600,  기울기=2.0830,  절편=-14.2296
# epoch=2600,  기울기=2.0830,  절편=-14.2296
# epoch=2600,  기울기=2.0830,  절편=-14.2296
# epoch=2700,  기울기=2.1091,  절편=-14.4178
# epoch=2700,  기울기=2.1086,  절편=-14.4180
# epoch=2700,  기울기=2.0648,  절편=-14.4253
# epoch=2700,  기울기=2.1087,  절편=-14.4198
# epoch=2700,  기울기=2.1093,  절편=-14.4197
# epoch=2700,  기울기=2.1093,  절편=-14.4197
# epoch=2700,  기울기=2.1093,  절편=-14.4197
# epoch=2800,  기울기=2.1347,  절편=-14.6025
# epoch=2800,  기울기=2.1342,  절편=-14.6026
# epoch=2800,  기울기=2.0915,  절편=-14.6097
# epoch=2800,  기울기=2.1343,  절편=-14.6044
# epoch=2800,  기울기=2.1349,  절편=-14.6043
# epoch=2800,  기울기=2.1349,  절편=-14.6043
# epoch=2800,  기울기=2.1349,  절편=-14.6043
# epoch=2900,  기울기=2.1595,  절편=-14.7820
# epoch=2900,  기울기=2.1591,  절편=-14.7821
# epoch=2900,  기울기=2.1175,  절편=-14.7890
# epoch=2900,  기울기=2.1592,  절편=-14.7838
# epoch=2900,  기울기=2.1598,  절편=-14.7837
# epoch=2900,  기울기=2.1598,  절편=-14.7837
# epoch=2900,  기울기=2.1598,  절편=-14.7837
# epoch=3000,  기울기=2.1838,  절편=-14.9566
# epoch=3000,  기울기=2.1834,  절편=-14.9567
# epoch=3000,  기울기=2.1428,  절편=-14.9635
# epoch=3000,  기울기=2.1835,  절편=-14.9584
# epoch=3000,  기울기=2.1840,  절편=-14.9583
# epoch=3000,  기울기=2.1840,  절편=-14.9583
# epoch=3000,  기울기=2.1840,  절편=-14.9583

# %%
plt.scatter(x_data, y_data)
plt.xlim(0, 15)
plt.ylim(-.1, 1.1)
x_range = (np.arange(0, 15, 0.1)) #그래프로 나타낼 x값의 범위를 정합니다.
plt.plot(np.arange(0, 15, 0.1), np.array([sigmoid(a*x + b) for x in x_range]))
plt.show()
